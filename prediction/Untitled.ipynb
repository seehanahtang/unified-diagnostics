# %%
import pandas as pd
import numpy as np
data_dir = "../data/"
data_path = "/orcd/pool/003/dbertsim_shared/ukb/"

# %%
df = pd.read_csv(f"{data_path}blood_protein_cancers_clean_new.csv")

# %%
cancer_types = ["skin","breast","prostate","colorectal","lung","lymphoma","kidney","leukemia","bladder","pancreatic","brain","stomach"]
time_cols = [f"{c}_cancer_time_to_diagnosis" for c in cancer_types]

# %%
df[time_cols]
# Out:
#        skin_cancer_time_to_diagnosis  breast_cancer_time_to_diagnosis  \
# 0                           1.886379                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
# ...                              ...                              ...
# 52990                            NaN                              NaN
# 52991                            NaN                              NaN
# 52992                            NaN                              NaN
# 52993                            NaN                              NaN
# 52994                      -1.303217                              NaN
#
#        prostate_cancer_time_to_diagnosis  colorectal_cancer_time_to_diagnosis  \
# ...

# %%
df[time_cols].notna().any(axis=1).sum()
# Out:
# 9942

# %%
df[time_cols].describe(include='all')
# Out:
#        skin_cancer_time_to_diagnosis  breast_cancer_time_to_diagnosis  \
# count                    4465.000000                      1885.000000
# mean                        3.304128                        -0.294221
# std                         7.129546                         8.137511
# min                       -40.977413                       -37.467488
# 25%                        -0.939083                        -6.006845
# 50%                         4.766598                         0.851472
# 75%                         8.810404                         6.349076
# max                        15.216975                        14.390144
#
#        prostate_cancer_time_to_diagnosis  colorectal_cancer_time_to_diagnosis  \
# count                        1670.000000                           944.000000
# mean                            4.494936                             3.518887
# std                             5.272491                             6.464786
# ...

# %%
cancer_groups = [
        "oral_pharynx_cancer",
        "digestive_organs_cancer",       
        "respiratory_intrathoracic_cancer",     
        "skin_cancer",
        "mesothelial_soft_tissue_cancer",
        "breast_cancer",
        "female_genital_cancer",
        "male_genital_cancer",
        "urinary_tract_cancer",
        "eye_brain_cns_cancer",
        "endocrine_cancer",
        "ill_defined_secondary_cancer",
        "in_situ_cancer",
        "hematologic_cancer",
        "bone_cartilage_cancer", # get rid of this one for now
        ]
time_group_cols = [f"{c}_time_to_diagnosis" for c in cancer_groups]
df[time_group_cols].notna().any(axis=1).sum()
# Out:
# 12356

# %%
9942/12356
# Out:
# 0.8046293298802202
