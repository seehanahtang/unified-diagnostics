# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

import xgboost as xgb
# import shap # can't use shap on jupyter notebook

# %%
import pandas as pd
train_df  = pd.read_csv('/orcd/pool/003/dbertsim_shared/ukb/ukb_cancer_train.csv')
# Out:
# /tmp/ipykernel_39460/1725433322.py:2: DtypeWarning: Columns (3028,3030,3031) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df  = pd.read_csv('/orcd/pool/003/dbertsim_shared/ukb/ukb_cancer_train.csv')

# %%
train_df.loc[(train_df['Sex_male'] == 0) & (train_df['prostate_cancer'] == 1)]
# Out:
# Empty DataFrame
# Columns: [eid, Age at recruitment, Sex_male, Ethnic background, Body mass index (BMI), Systolic blood pressure, automated reading, Diastolic blood pressure, automated reading, Townsend deprivation index at recruitment, Smoking status, Alcohol intake frequency., Illnesses of father, Illnesses of mother, Illnesses of siblings, Medication for cholesterol, blood pressure or diabetes, Operation code, Operation code.1, Operation code.2, Operation code.3, Operation code.4, Interpolated Age of participant when operation took place, Interpolated Age of participant when operation took place.1, Interpolated Age of participant when operation took place.2, Interpolated Age of participant when operation took place.3, Interpolated Age of participant when operation took place.4, olink_a1bg, olink_aamdc, olink_aarsd1, olink_abca2, olink_abhd14b, olink_abl1, olink_abo, olink_abraxas2, olink_acaa1, olink_acadm, olink_acadsb, olink_acan, olink_ace, olink_ace2, olink_ache, olink_acot13, olink_acox1, olink_acp1, olink_acp5, olink_acp6, olink_acrbp, olink_acrv1, olink_acsl1, olink_acta2, olink_actn2, olink_actn4, olink_acvrl1, olink_acy1, olink_acy3, olink_acyp1, olink_ada, olink_ada2, olink_adam12, olink_adam15, olink_adam22, olink_adam23, olink_adam8, olink_adam9, olink_adamts1, olink_adamts13, olink_adamts15, olink_adamts16, olink_adamts4, olink_adamts8, olink_adamtsl2, olink_adamtsl4, olink_adamtsl5, olink_adcyap1r1, olink_add1, olink_adgrb3, olink_adgrd1, olink_adgre1, olink_adgre2, olink_adgre5, olink_adgrf5, olink_adgrg1, olink_adgrg2, olink_adgrv1, olink_adh1b, olink_adh4, olink_adipoq, olink_adm, olink_adra2a, olink_afap1, olink_afm, olink_afp, olink_agbl2, olink_ager, olink_agr2, olink_agr3, olink_agrn, olink_agrp, olink_agt, olink_agxt, olink_ahcy, olink_ahnak, ...]
# Index: []
#
# [0 rows x 3032 columns]

# %%
train_df.loc[(train_df['Sex_male'] == 1) & (train_df['breast_cancer'] == 1)]
# Out:
#            eid  Age at recruitment  Sex_male Ethnic background  \
# 10189  4029969                  61         1           British
# 11455  5058485                  59         1           British
# 13643  1744075                  67         1           British
#
#        Body mass index (BMI)  Systolic blood pressure, automated reading  \
# 10189                29.4229                                       127.0
# 11455                30.6513                                       161.0
# 13643                26.0540                                       140.0
#
#        Diastolic blood pressure, automated reading  \
# 10189                                         76.0
# 11455                                        104.0
# 13643                                         72.0
#
#        Townsend deprivation index at recruitment Smoking status  \
# 10189                                      -2.50          Never
# 11455                                      -3.63          Never
# 13643                                       5.66       Previous
#
#         Alcohol intake frequency.  ... prostate_time_to_diagnosis cancer  \
# 10189      Special occasions only  ...                        NaN      1
# 11455        Once or twice a week  ...                        NaN      1
# 13643  One to three times a month  ...                        NaN      1
#
#       cancer_time_to_diagnosis cancer_strata breast_strata prostate_strata  \
# 10189                -2.392882            <0            <0             NaN
# 11455                -5.971253            <0            <0             NaN
# 13643                -4.939083            <0            <0             NaN
#
#       lung_strata colorectal_strata bladder_strata  pancreatic_strata
# 10189         NaN               NaN            NaN                NaN
# 11455         NaN               NaN            NaN                NaN
# 13643         NaN               NaN            NaN                NaN
#
# [3 rows x 3032 columns]

# %%
train_df.loc[(train_df['breast_cancer'] == 1)]
# Out:
#            eid  Age at recruitment  Sex_male           Ethnic background  \
# 7      1005250                  52         0                     British
# 101    1077666                  66         0                       Irish
# 115    1084841                  61         0                     British
# 134    1099072                  63         0  Any other white background
# 219    1164947                  60         0                     British
# ...        ...                 ...       ...                         ...
# 31224  5551227                  57         0                     British
# 31239  5562708                  69         0                     British
# 31350  5663563                  65         0                     British
# 31547  5826156                  70         0                     British
# 31773  6002963                  64         0                     British
#
#        Body mass index (BMI)  Systolic blood pressure, automated reading  \
# 7                    20.5859                                       159.0
# 101                  35.0046                                       139.0
# 115                  19.8010                                       127.0
# 134                  23.8248                                       156.0
# 219                  24.2810                                       150.0
# ...                      ...                                         ...
# 31224                25.5006                                       138.0
# 31239                29.1523                                         NaN
# 31350                32.9380                                       182.0
# 31547                19.5239                                       155.0
# 31773                27.6122                                       121.0
#
#        Diastolic blood pressure, automated reading  \
# 7                                             89.0
# 101                                           87.0
# 115                                           84.0
# 134                                           95.0
# 219                                           89.0
# ...                                            ...
# 31224                                         75.0
# 31239                                          NaN
# 31350                                         80.0
# 31547                                         79.0
# 31773                                         80.0
#
#        Townsend deprivation index at recruitment Smoking status  \
# 7                                          -5.24          Never
# 101                                        -2.41          Never
# 115                                        -5.04          Never
# 134                                        -0.25          Never
# 219                                        -3.30       Previous
# ...                                          ...            ...
# 31224                                      -4.91          Never
# 31239                                       2.58          Never
# 31350                                       0.14          Never
# 31547                                      -1.24       Previous
# 31773                                       2.66       Previous
#
#         Alcohol intake frequency.  ... prostate_time_to_diagnosis cancer  \
# 7          Special occasions only  ...                        NaN      1
# 101    Three or four times a week  ...                        NaN      1
# 115          Once or twice a week  ...                        NaN      1
# 134         Daily or almost daily  ...                        NaN      1
# 219    Three or four times a week  ...                        NaN      1
# ...                           ...  ...                        ...    ...
# 31224        Once or twice a week  ...                        NaN      1
# 31239        Once or twice a week  ...                        NaN      1
# 31350                       Never  ...                        NaN      1
# 31547       Daily or almost daily  ...                        NaN      1
# 31773       Daily or almost daily  ...                        NaN      1
#
#       cancer_time_to_diagnosis cancer_strata breast_strata prostate_strata  \
# 7                    -1.032170            <0            <0             NaN
# 101                 -20.235455            <0            <0             NaN
# 115                 -19.624914            <0            <0             NaN
# 134                  -3.019849            <0            <0             NaN
# 219                  -5.598905            <0            <0             NaN
# ...                        ...           ...           ...             ...
# 31224                -6.042437            <0            <0             NaN
# 31239                -1.363450            <0            <0             NaN
# 31350                -3.857632            <0            <0             NaN
# 31547                -5.423682            <0            <0             NaN
# 31773                -2.551677            <0            <0             NaN
#
#       lung_strata colorectal_strata bladder_strata  pancreatic_strata
# 7             NaN               NaN            NaN                NaN
# 101           NaN               NaN            NaN                NaN
# 115           NaN               NaN            NaN                NaN
# 134           NaN               NaN            NaN                NaN
# 219           NaN               NaN            NaN                NaN
# ...           ...               ...            ...                ...
# 31224         NaN               NaN            NaN                NaN
# 31239         NaN               NaN            NaN                NaN
# 31350         NaN               NaN            NaN                NaN
# 31547         NaN               NaN            NaN                NaN
# 31773         NaN               NaN            NaN                NaN
#
# [604 rows x 3032 columns]

# %%
def get_data(outcome: str):

    train_df = pd.read_csv('/orcd/pool/003/dbertsim_shared/ukb/ukb_cancer_train.csv')
    val_df   = pd.read_csv('/orcd/pool/003/dbertsim_shared/ukb/ukb_cancer_valid.csv')
    test_df  = pd.read_csv('/orcd/pool/003/dbertsim_shared/ukb/ukb_cancer_test.csv')

    outcome_col = f"{outcome}_cancer"

    df_all = pd.concat([train_df, val_df, test_df])
    olink_cols = [c for c in df_all.columns if "olink" in c]

    missing_pct = df_all[olink_cols].isnull().mean()
    selected_cols = missing_pct[missing_pct < 0.4].index # can tune this proportion

    print(f"Selected {len(selected_cols)} features with < 40% missingness.")

    def split_xy(df_):
        return df_[selected_cols], df_[outcome_col].values

    X_train, y_train = split_xy(train_df)
    X_valid, y_valid = split_xy(val_df)
    X_test,  y_test  = split_xy(test_df)
    
    X_trainvalid = pd.concat([X_train, X_valid], axis=0)
    y_trainvalid = np.concatenate((y_train, y_valid))
    

    return X_trainvalid, y_trainvalid, X_test, y_test

def stability_selection_elastic_net(
    X_df,
    y,
    n_bootstrap=100,
    sample_frac=0.75,
    C=0.1,
    l1_ratio=0.5,
    random_state=42
):
    """
    Stability selection using logistic regression with elastic net penalty.
    X_df: pandas DataFrame of features (columns = protein IDs/names)
    y:    1D array-like of labels
    """
    rng = np.random.RandomState(random_state)
    X = X_df.values  # use numpy internally
    feature_names = X_df.columns.to_list()

    n_samples, n_features = X.shape

    selection_counts = np.zeros(n_features, dtype=int)
    coeff_sum = np.zeros(n_features, dtype=float)

    # Pipeline: standardize + elastic net logistic regression
    base_model = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),  # or "mean"
        ("scaler", StandardScaler()),
        ("logreg", LogisticRegression(
            penalty="elasticnet",
            solver="saga",
            l1_ratio=l1_ratio,
            C=C,
            max_iter=5000,
            random_state=rng,
            n_jobs=-1
        ))
    ])

    for b in range(n_bootstrap):
        # Bootstrap sample indices
        idx = rng.choice(n_samples, size=int(sample_frac * n_samples), replace=True)
        X_b = X[idx]
        y_b = np.asarray(y)[idx]

        base_model.fit(X_b, y_b)

        # Extract coefficients
        coef = base_model.named_steps["logreg"].coef_.ravel()  # shape (n_features,)

        nonzero = coef != 0
        selection_counts[nonzero] += 1
        coeff_sum[nonzero] += np.abs(coef[nonzero])

    selection_freq = selection_counts / n_bootstrap
    avg_coeff = np.divide(
        coeff_sum,
        np.maximum(selection_counts, 1),  # avoid div-by-zero
        where=selection_counts > 0
    )

    stab_df = pd.DataFrame({
        "feature": feature_names,
        "selection_freq": selection_freq,
        "avg_abs_coef": avg_coeff
    }).sort_values("selection_freq", ascending=False)

    return stab_df.reset_index(drop=True)

# %%
# ----- CONFIG -----
outcome = "breast"   # <-- change to your outcome column name

# X_train, y_train, X_test, y_test = get_data(outcome)

stab_df = stability_selection_elastic_net(
    X_train, y_train,
    n_bootstrap=100,   # can increase to 200+ if time allows
    sample_frac=0.75,
    C=0.1,
    l1_ratio=0.5,
    random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 6
#       2 outcome = "breast"   # <-- change to your outcome column name
#       4 # X_train, y_train, X_test, y_test = get_data(outcome)
# ----> 6 stab_df = stability_selection_elastic_net(
#       7     X_train, y_train,
#       8     n_bootstrap=100,   # can increase to 200+ if time allows
#       9     sample_frac=0.75,
#      10     C=0.1,
#      11     l1_ratio=0.5,
#      12     random_state=42
#      13 )
#
# Cell In[22], line 74, in stability_selection_elastic_net(X_df, y, n_bootstrap, sample_frac, C, l1_ratio, random_state)
#      71 X_b = X[idx]
#      72 y_b = np.asarray(y)[idx]
# ---> 74 base_model.fit(X_b, y_b)
#      76 # Extract coefficients
#      77 coef = base_model.named_steps["logreg"].coef_.ravel()  # shape (n_features,)
#
# File /home/software/anaconda3/2023.07/lib/python3.11/site-packages/sklearn/pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     407 return self
#
# File /home/software/anaconda3/2023.07/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1291, in LogisticRegression.fit(self, X, y, sample_weight)
#    1288 else:
#    1289     n_threads = 1
# -> 1291 fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1292     path_func(
#    1293         X,
#    1294         y,
#    1295         pos_class=class_,
#    1296         Cs=[C_],
#    1297         l1_ratio=self.l1_ratio,
#    1298         fit_intercept=self.fit_intercept,
#    1299         tol=self.tol,
#    1300         verbose=self.verbose,
#    1301         solver=solver,
#    1302         multi_class=multi_class,
#    1303         max_iter=self.max_iter,
#    1304         class_weight=self.class_weight,
#    1305         check_input=False,
#    1306         random_state=self.random_state,
#    1307         coef=warm_start_coef_,
#    1308         penalty=penalty,
#    1309         max_squared_sum=max_squared_sum,
#    1310         sample_weight=sample_weight,
#    1311         n_threads=n_threads,
#    1312     )
#    1313     for class_, warm_start_coef_ in zip(classes_, warm_start_coef)
#    1314 )
#    1316 fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#    1317 self.n_iter_ = np.asarray(n_iter_, dtype=np.int32)[:, 0]
#
# File /home/software/anaconda3/2023.07/lib/python3.11/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /home/software/anaconda3/2023.07/lib/python3.11/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File /home/software/anaconda3/2023.07/lib/python3.11/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File /home/software/anaconda3/2023.07/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /home/software/anaconda3/2023.07/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /home/software/anaconda3/2023.07/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File /home/software/anaconda3/2023.07/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
